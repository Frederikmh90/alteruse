# %%
import polars as pl

# %%
df = pl.read_excel("../data/processed/facebook_accounts_summary_20250526_224604.xlsx")

# %%
df.shape
# Out:
# (140, 10)

# %%
df
# Out:
# shape: (140, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ account_n ┆ earliest_ ┆ latest_ac ┆ activity_ ┆ … ┆ alternati ┆ other_url ┆ total_new ┆ unique_d │
# │ ame       ┆ activity  ┆ tivity    ┆ days      ┆   ┆ ve_news_s ┆ s_shared  ┆ s_pages_l ┆ omains_s │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ hared     ┆ ---       ┆ iked      ┆ hared    │
# │ str       ┆ str       ┆ str       ┆ i64       ┆   ┆ ---       ┆ i64       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ i64       ┆           ┆ i64       ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 474-4477- ┆ 1970-01-0 ┆ 2025-05-0 ┆ 20209     ┆ … ┆ 0         ┆ 27        ┆ 427       ┆ 16       │
# │ c-146294_ ┆ 1T00:00:0 ┆ 1T18:00:5 ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df_browser = pl.read_excel("../data/processed/browser_history_metrics_20250526_232728.xlsx",infer_schema_length=0)

# %%
df_browser
# Out:
# shape: (157, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ total_vis ┆ unique_ur ┆ unique_do ┆ mainstrea ┆ … ┆ news_doma ┆ account_n ┆ data_sour ┆ source_f │
# │ its       ┆ ls        ┆ mains     ┆ m_news_vi ┆   ┆ ins       ┆ ame       ┆ ce        ┆ ile      │
# │ ---       ┆ ---       ┆ ---       ┆ sits      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆           ┆ str       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2177      ┆ 1324      ┆ 195       ┆ 18        ┆ … ┆ {'politik ┆ Kantar_do ┆ safari_db ┆ 474-4477 │
# │           ┆           ┆           ┆           ┆   ┆ en.dk':   ┆ wnload_39 ┆           ┆ -c-14675 │
# ...
