# %%
import polars as pl

df = pl.read_csv("../../../data/url_extract/extracted_urls_optimized.csv")

df.head()
# Out:
# shape: (5, 9)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ url        ┆ resolved_ ┆ domain    ┆ content ┆ … ┆ first_see ┆ last_seen ┆ visit_cou ┆ source_fi │
# │ ---        ┆ url       ┆ ---       ┆ ---     ┆   ┆ n         ┆ ---       ┆ nt        ┆ les       │
# │ str        ┆ ---       ┆ str       ┆ str     ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │            ┆ str       ┆           ┆         ┆   ┆ str       ┆           ┆ i64       ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ https://ho ┆ null      ┆ hometrain ┆ null    ┆ … ┆ 2025-05-1 ┆ 2025-05-1 ┆ 1         ┆ 474-4477- │
# │ metrainer. ┆           ┆ er.dk     ┆         ┆   ┆ 9 09:22:4 ┆ 9 09:22:4 ┆           ┆ c-146752_ │
# │ dk/images/ ┆           ┆           ┆         ┆   ┆ 5.070187+ ┆ 5.070187+ ┆           ┆ 2025-05-1 │
# ...

# %%
df
# Out:
# shape: (633_415, 9)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ url        ┆ resolved_ ┆ domain    ┆ content ┆ … ┆ first_see ┆ last_seen ┆ visit_cou ┆ source_fi │
# │ ---        ┆ url       ┆ ---       ┆ ---     ┆   ┆ n         ┆ ---       ┆ nt        ┆ les       │
# │ str        ┆ ---       ┆ str       ┆ str     ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │            ┆ str       ┆           ┆         ┆   ┆ str       ┆           ┆ i64       ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ https://ho ┆ null      ┆ hometrain ┆ null    ┆ … ┆ 2025-05-1 ┆ 2025-05-1 ┆ 1         ┆ 474-4477- │
# │ metrainer. ┆           ┆ er.dk     ┆         ┆   ┆ 9 09:22:4 ┆ 9 09:22:4 ┆           ┆ c-146752_ │
# │ dk/images/ ┆           ┆           ┆         ┆   ┆ 5.070187+ ┆ 5.070187+ ┆           ┆ 2025-05-1 │
# ...
